# %% [markdown]
# ## Top 250 Korean Dramas (KDrama) Dataset
#
# https://www.kaggle.com/datasets/ahbab911/top-250-korean-dramas-kdrama-dataset/data
#
# Dataset of top 250 kdramas from 2003 to 2022 from kaggle.com. The dataset is derived from mydramalist.com

# %% [markdown]
# ## Data cleaning

# %%
# Read CSV file

import pandas as pd

df = pd.read_csv('C:\\Users\\User\\Desktop\\python\\github\\kdrama.csv' )
pd.set_option('display.max_columns', None)

# %%
# Let's see how the records look like. 

df.head()
# Out:
#                   Name                   Aired Date  Year of release  \
# 0       Move to Heaven                 May 14, 2021             2021
# 1       Flower of Evil  Jul 29, 2020 - Sep 23, 2020             2020
# 2    Hospital Playlist  Mar 12, 2020 - May 28, 2020             2020
# 3  Hospital Playlist 2  Jun 17, 2021 - Sep 16, 2021             2021
# 4            My Mister  Mar 21, 2018 - May 17, 2018             2018
#
#   Original Network              Aired On  Number of Episodes       Duration  \
# 0          Netflix                Friday                  10        52 min.
# 1              tvN   Wednesday, Thursday                  16  1 hr. 10 min.
# 2   Netflix,  tvN               Thursday                  12  1 hr. 30 min.
# 3   Netflix,  tvN               Thursday                  12  1 hr. 40 min.
# 4              tvN   Wednesday, Thursday                  16  1 hr. 17 min.
#
#                           Content Rating  Rating  \
# 0  18+ Restricted (violence & profanity)     9.2
# 1                15+ - Teens 15 or older     9.1
# 2                15+ - Teens 15 or older     9.1
# 3                15+ - Teens 15 or older     9.1
# 4                15+ - Teens 15 or older     9.1
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  Although Baek Hee Sung is hiding a dark secret...
# 2  The stories of people going through their days...
# 3  Everyday is extraordinary for five doctors and...
# 4  Park Dong Hoon is a middle-aged engineer who i...
#
#                                      Genre  \
# 0                   Life,  Drama,  Family
# 1  Thriller,  Romance,  Crime,  Melodrama
# 2   Friendship,  Romance,  Life,  Medical
# 3   Friendship,  Romance,  Life,  Medical
# 4   Psychological,  Life,  Drama,  Family
#
#                                                 Tags  \
# 0  Autism, Uncle-Nephew Relationship, Death, Sava...
# 1  Married Couple, Deception, Suspense, Family Se...
# 2  Strong Friendship, Multiple Mains, Best Friend...
# 3  Workplace, Strong Friendship, Best Friends, Mu...
# 4  Age Gap, Nice Male Lead, Strong Female Lead, H...
#
#                      Director    Screenwriter  \
# 0                 Kim Sung Ho    Yoon Ji Ryun
# 1  Kim Chul Gyu, Yoon Jong Ho    Yoo Jung Hee
# 2                 Shin Won Ho    Lee Woo Jung
# 3                 Shin Won Ho    Lee Woo Jung
# 4   Kim Won Suk, Kim Sang Woo  Park Hae Young
#
#                                                 Cast  \
# 0  Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, Ju...
# 1  Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo ...
# 2  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 3  Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Kim...
# 4  Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk, ...
#
#                    Production companies Rank
# 0  Page One Film, Number Three Pictures   #1
# 1                         Monster Union   #2
# 2                 Egg Is Coming, CJ ENM   #3
# 3                 Egg Is Coming, CJ ENM   #4
# 4                      Chorokbaem Media   #5

# %%
# Let's get some info of the data frame.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  250 non-null    object
#  1   Aired Date            250 non-null    object
#  2   Year of release       250 non-null    int64
#  3   Original Network      250 non-null    object
#  4   Aired On              250 non-null    object
#  5   Number of Episodes    250 non-null    int64
#  6   Duration              250 non-null    object
#  7   Content Rating        245 non-null    object
#  8   Rating                250 non-null    float64
#  9   Synopsis              250 non-null    object
#  10  Genre                 250 non-null    object
#  11  Tags                  250 non-null    object
#  12  Director              249 non-null    object
#  13  Screenwriter          249 non-null    object
#  14  Cast                  250 non-null    object
#  15  Production companies  248 non-null    object
#  16  Rank                  250 non-null    object
# dtypes: float64(1), int64(2), object(14)
# memory usage: 33.3+ KB

# %% [markdown]
# Convert columns Original Network, Aired On, Genre, Tags, Cast and Director, Screenwriter, Production companies (the last three columns have NaN) from object type to list.

# %%
cols = ['Original Network', 'Aired On', 'Genre', 'Tags', 'Cast', 'Director', 'Screenwriter', 'Production companies']
df[cols] = df[cols].fillna('').apply(lambda col: col.str.split(',').apply(lambda x: [i.strip() for i in x]))

df[cols].head()
# Out:
#   Original Network               Aired On  \
# 0        [Netflix]               [Friday]
# 1            [tvN]  [Wednesday, Thursday]
# 2   [Netflix, tvN]             [Thursday]
# 3   [Netflix, tvN]             [Thursday]
# 4            [tvN]  [Wednesday, Thursday]
#
#                                    Genre  \
# 0                  [Life, Drama, Family]
# 1  [Thriller, Romance, Crime, Melodrama]
# 2   [Friendship, Romance, Life, Medical]
# 3   [Friendship, Romance, Life, Medical]
# 4   [Psychological, Life, Drama, Family]
#
#                                                 Tags  \
# 0  [Autism, Uncle-Nephew Relationship, Death, Sav...
# 1  [Married Couple, Deception, Suspense, Family S...
# 2  [Strong Friendship, Multiple Mains, Best Frien...
# 3  [Workplace, Strong Friendship, Best Friends, M...
# 4  [Age Gap, Nice Male Lead, Strong Female Lead, ...
#
#                                                 Cast  \
# 0  [Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, J...
# 1  [Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo...
# 2  [Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Ki...
# 3  [Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Ki...
# 4  [Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk,...
#
#                        Director      Screenwriter  \
# 0                 [Kim Sung Ho]    [Yoon Ji Ryun]
# 1  [Kim Chul Gyu, Yoon Jong Ho]    [Yoo Jung Hee]
# 2                 [Shin Won Ho]    [Lee Woo Jung]
# 3                 [Shin Won Ho]    [Lee Woo Jung]
# 4   [Kim Won Suk, Kim Sang Woo]  [Park Hae Young]
#
#                      Production companies
# 0  [Page One Film, Number Three Pictures]
# 1                         [Monster Union]
# 2                 [Egg Is Coming, CJ ENM]
# 3                 [Egg Is Coming, CJ ENM]
# 4                      [Chorokbaem Media]

# %% [markdown]
# Convert Aired Date column into two columns Start Date and Finish Date. If all the episodes have been released the same day, then Start and Finish Date are the same.

# %%
# Split 'Aired Date' into two columns 'Start Date' and 'Finish Date'
df[['Start Date', 'Finish Date']] = df['Aired Date'].str.split(' - ', expand=True)

# Convert both columns to datetime
df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce', format='%b %d, %Y')
df['Finish Date'] = pd.to_datetime(df['Finish Date'], errors='coerce', format='%b %d, %Y')

# If 'Finish Date' is NaN (only one date was provided), set it equal to 'Start Date'
df['Finish Date'].fillna(df['Start Date'], inplace=True)

print(df[['Start Date', 'Finish Date']])
# Out:
#     Start Date Finish Date
# 0   2021-05-14  2021-05-14
# 1   2020-07-29  2020-09-23
# 2   2020-03-12  2020-05-28
# 3   2021-06-17  2021-09-16
# 4   2018-03-21  2018-05-17
# ..         ...         ...
# 245 2017-08-12  2017-10-01
# 246 2017-05-31  2017-08-03
# 247 2016-03-18  2016-05-07
# 248 2017-12-23  2018-03-04
# 249 2021-06-18  2021-07-31
#
# [250 rows x 2 columns]
# C:\Users\User\AppData\Local\Temp\ipykernel_27444\2764403551.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Finish Date'].fillna(df['Start Date'], inplace=True)

# %% [markdown]
# Convert column Duration from object type to timedelta.

# %%
# Extract hours and minutes
df[['Hours', 'Minutes']] = df['Duration'].str.extract(r'(?:(\d+) hr\.)?\s*(\d+) min\.')

# Fill NaN hours with 0 and convert to integers
df['Hours'] = df['Hours'].fillna(0).astype(int)
df['Minutes'] = df['Minutes'].astype(int)

# Convert to timedelta
df['Duration'] = pd.to_timedelta(df['Hours'], unit='h') + pd.to_timedelta(df['Minutes'], unit='m')

# Delete unnecessary columns
df.drop(['Aired Date','Hours', 'Minutes', 'Rank'], axis=1, inplace=True)

print(df.head())
# Out:
#                   Name  Year of release Original Network  \
# 0       Move to Heaven             2021        [Netflix]
# 1       Flower of Evil             2020            [tvN]
# 2    Hospital Playlist             2020   [Netflix, tvN]
# 3  Hospital Playlist 2             2021   [Netflix, tvN]
# 4            My Mister             2018            [tvN]
#
#                 Aired On  Number of Episodes        Duration  \
# 0               [Friday]                  10 0 days 00:52:00
# 1  [Wednesday, Thursday]                  16 0 days 01:10:00
# 2             [Thursday]                  12 0 days 01:30:00
# 3             [Thursday]                  12 0 days 01:40:00
# 4  [Wednesday, Thursday]                  16 0 days 01:17:00
#
#                           Content Rating  Rating  \
# 0  18+ Restricted (violence & profanity)     9.2
# 1                15+ - Teens 15 or older     9.1
# 2                15+ - Teens 15 or older     9.1
# 3                15+ - Teens 15 or older     9.1
# 4                15+ - Teens 15 or older     9.1
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  Although Baek Hee Sung is hiding a dark secret...
# 2  The stories of people going through their days...
# 3  Everyday is extraordinary for five doctors and...
# 4  Park Dong Hoon is a middle-aged engineer who i...
#
#                                    Genre  \
# 0                  [Life, Drama, Family]
# 1  [Thriller, Romance, Crime, Melodrama]
# 2   [Friendship, Romance, Life, Medical]
# 3   [Friendship, Romance, Life, Medical]
# 4   [Psychological, Life, Drama, Family]
#
#                                                 Tags  \
# 0  [Autism, Uncle-Nephew Relationship, Death, Sav...
# 1  [Married Couple, Deception, Suspense, Family S...
# 2  [Strong Friendship, Multiple Mains, Best Frien...
# 3  [Workplace, Strong Friendship, Best Friends, M...
# 4  [Age Gap, Nice Male Lead, Strong Female Lead, ...
#
#                        Director      Screenwriter  \
# 0                 [Kim Sung Ho]    [Yoon Ji Ryun]
# 1  [Kim Chul Gyu, Yoon Jong Ho]    [Yoo Jung Hee]
# 2                 [Shin Won Ho]    [Lee Woo Jung]
# 3                 [Shin Won Ho]    [Lee Woo Jung]
# 4   [Kim Won Suk, Kim Sang Woo]  [Park Hae Young]
#
#                                                 Cast  \
# 0  [Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, J...
# 1  [Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo...
# 2  [Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Ki...
# 3  [Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Ki...
# 4  [Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk,...
#
#                      Production companies Start Date Finish Date
# 0  [Page One Film, Number Three Pictures] 2021-05-14  2021-05-14
# 1                         [Monster Union] 2020-07-29  2020-09-23
# 2                 [Egg Is Coming, CJ ENM] 2020-03-12  2020-05-28
# 3                 [Egg Is Coming, CJ ENM] 2021-06-17  2021-09-16
# 4                      [Chorokbaem Media] 2018-03-21  2018-05-17

# %% [markdown]
# Fill in missing Content Ratings where the info can be found on the Internet.

# %%
# Check what are the values in column Content Rating.

print(df['Content Rating'].unique())

# Filter the rows where 'Content Rating' column is NaN.

filtered_df = df[df['Content Rating'].isna()]
filtered_df
# Out:
# ['18+ Restricted (violence & profanity)' '15+ - Teens 15 or older'
#  '13+ - Teens 13 or older' nan 'G - All Ages']
#                      Name  Year of release Original Network  \
# 140     One Dollar Lawyer             2022            [SBS]
# 146                  Duel             2017            [OCN]
# 171                Player             2018            [OCN]
# 190  The Mysterious Class             2021        [YouTube]
# 230             Liar Game             2014            [tvN]
#
#                Aired On  Number of Episodes        Duration Content Rating  \
# 140  [Friday, Saturday]                  12 0 days 01:10:00            NaN
# 146  [Saturday, Sunday]                  16 0 days 01:03:00            NaN
# 171  [Saturday, Sunday]                  14 0 days 01:05:00            NaN
# 190            [Friday]                   8 0 days 00:20:00            NaN
# 230   [Monday, Tuesday]                  12 0 days 01:03:00            NaN
#
#      Rating                                           Synopsis  \
# 140     8.4  Cheon Ji Hun is a lawyer with unusual flair. H...
# 146     8.4  Jang Deuk Cheon, a hardened detective cop whos...
# 171     8.4  A police redemption team consisting of a swind...
# 190     8.3  "There are 21 students in our class." "What ar...
# 230     8.3  Various contestants take part in a game show w...
#
#                                          Genre  \
# 140                       [Comedy, Law, Drama]
# 146                [Thriller, Mystery, Sci-Fi]
# 171        [Action, Thriller, Mystery, Comedy]
# 190     [Mystery, Horror, Youth, Supernatural]
# 230  [Thriller, Mystery, Psychological, Drama]
#
#                                                   Tags         Director  \
# 140  [Lawyer Male Lead, Former Prosecutor Male Lead...   [Kim Jae Hyun]
# 146  [Amnesia, Human Experimentation, Kidnapping, T...   [Lee Jong Jae]
# 171  [Strong Female Lead, Corruption, Hidden Identi...    [Go Jae Hyun]
# 190  [Student, Ghost, Investigation, High School, S...      [Ha Han Me]
# 230  [Naive Female Lead, Debt, Game Show, Swindler ...  [Kim Hong Seon]
#
#                         Screenwriter  \
# 140  [Choi Soo Jin, Choi Chang Hwan]
# 146                   [Kim Yoon Joo]
# 171                 [Shin Jae Hyung]
# 190                    [Han Song-yi]
# 230                   [Ryu Yong Jae]
#
#                                                   Cast  \
# 140  [Namkoong Min, Kim Ji Eun, Choi Dae Hoon, Lee ...
# 146  [Jung Jae Young, Kim Jung Eun, Yang Se Jong, S...
# 171  [Song Seung Heon, Krystal Jung, Lee Si Eon, Ta...
# 190  [Choi Hyun Suk, Park Ji Hoon, Yoshi, Kim Jun K...
# 230  [Lee Sang Yoon, Kim So Eun, Shin Sung Rok, Cha...
#
#             Production companies Start Date Finish Date
# 140                   [Studio S] 2022-09-23  2022-11-11
# 146           [Chorokbaem Media] 2017-06-03  2017-07-23
# 171                [iWill Media] 2018-09-29  2018-11-11
# 190           [YG Entertainment] 2021-11-12  2021-12-31
# 230  [Apollo Pictures, Fantagio] 2014-10-20  2014-11-25

# %%
# Change the values in 'Content Rating' column with info found on the Internet.

df.loc[140, 'Content Rating'] = '13+ - Teens 13 or older'
df.loc[171, 'Content Rating'] = '15+ - Teens 15 or older'

# %% [markdown]
# ## Data analysis

# %% [markdown]
# Add a column calculating total length of kdrama.

# %%
df['Total Duration'] = df['Number of Episodes']*df['Duration']

# %% [markdown]
# Add a column describing how many days was kdrama aired.

# %%
df['Air Days'] = (df['Finish Date'] - df['Start Date']).dt.days

# %%
print(df.head())
# Out:
#                   Name  Year of release Original Network  \
# 0       Move to Heaven             2021        [Netflix]
# 1       Flower of Evil             2020            [tvN]
# 2    Hospital Playlist             2020   [Netflix, tvN]
# 3  Hospital Playlist 2             2021   [Netflix, tvN]
# 4            My Mister             2018            [tvN]
#
#                 Aired On  Number of Episodes        Duration  \
# 0               [Friday]                  10 0 days 00:52:00
# 1  [Wednesday, Thursday]                  16 0 days 01:10:00
# 2             [Thursday]                  12 0 days 01:30:00
# 3             [Thursday]                  12 0 days 01:40:00
# 4  [Wednesday, Thursday]                  16 0 days 01:17:00
#
#                           Content Rating  Rating  \
# 0  18+ Restricted (violence & profanity)     9.2
# 1                15+ - Teens 15 or older     9.1
# 2                15+ - Teens 15 or older     9.1
# 3                15+ - Teens 15 or older     9.1
# 4                15+ - Teens 15 or older     9.1
#
#                                             Synopsis  \
# 0  Geu Roo is a young autistic man. He works for ...
# 1  Although Baek Hee Sung is hiding a dark secret...
# 2  The stories of people going through their days...
# 3  Everyday is extraordinary for five doctors and...
# 4  Park Dong Hoon is a middle-aged engineer who i...
#
#                                    Genre  \
# 0                  [Life, Drama, Family]
# 1  [Thriller, Romance, Crime, Melodrama]
# 2   [Friendship, Romance, Life, Medical]
# 3   [Friendship, Romance, Life, Medical]
# 4   [Psychological, Life, Drama, Family]
#
#                                                 Tags  \
# 0  [Autism, Uncle-Nephew Relationship, Death, Sav...
# 1  [Married Couple, Deception, Suspense, Family S...
# 2  [Strong Friendship, Multiple Mains, Best Frien...
# 3  [Workplace, Strong Friendship, Best Friends, M...
# 4  [Age Gap, Nice Male Lead, Strong Female Lead, ...
#
#                        Director      Screenwriter  \
# 0                 [Kim Sung Ho]    [Yoon Ji Ryun]
# 1  [Kim Chul Gyu, Yoon Jong Ho]    [Yoo Jung Hee]
# 2                 [Shin Won Ho]    [Lee Woo Jung]
# 3                 [Shin Won Ho]    [Lee Woo Jung]
# 4   [Kim Won Suk, Kim Sang Woo]  [Park Hae Young]
#
#                                                 Cast  \
# 0  [Lee Je Hoon, Tang Jun Sang, Hong Seung Hee, J...
# 1  [Lee Joon Gi, Moon Chae Won, Jang Hee Jin, Seo...
# 2  [Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Ki...
# 3  [Jo Jung Suk, Yoo Yeon Seok, Jung Kyung Ho, Ki...
# 4  [Lee Sun Kyun, IU, Park Ho San, Song Sae Byuk,...
#
#                      Production companies Start Date Finish Date  \
# 0  [Page One Film, Number Three Pictures] 2021-05-14  2021-05-14
# 1                         [Monster Union] 2020-07-29  2020-09-23
# 2                 [Egg Is Coming, CJ ENM] 2020-03-12  2020-05-28
# 3                 [Egg Is Coming, CJ ENM] 2021-06-17  2021-09-16
# 4                      [Chorokbaem Media] 2018-03-21  2018-05-17
#
#    Total Duration  Air Days
# 0 0 days 08:40:00         0
# 1 0 days 18:40:00        56
# 2 0 days 18:00:00        77
# 3 0 days 20:00:00        91
# 4 0 days 20:32:00        57

# %%
# Summary statistics for numerical columns

df.describe()
# Out:
#        Year of release  Number of Episodes                   Duration  \
# count        250.00000          250.000000                        250
# mean        2018.25600           19.064000     0 days 01:02:24.480000
# min         2003.00000            1.000000            0 days 00:15:00
# 25%         2017.00000           16.000000            0 days 01:00:00
# 50%         2019.00000           16.000000            0 days 01:05:00
# 75%         2021.00000           20.000000            0 days 01:10:00
# max         2022.00000          133.000000            0 days 01:40:00
# std            3.26452           13.245743  0 days 00:14:57.421076168
#
#            Rating                  Start Date          Finish Date  \
# count  250.000000                         250                  250
# mean     8.534000  2018-10-02 13:20:38.400000  2018-11-27 01:55:12
# min      8.300000         2003-09-15 00:00:00  2004-03-23 00:00:00
# 25%      8.300000         2017-03-28 06:00:00  2017-06-09 00:00:00
# 50%      8.500000         2019-07-03 12:00:00  2019-08-22 12:00:00
# 75%      8.700000         2021-04-14 00:00:00  2021-06-05 12:00:00
# max      9.200000         2022-11-18 00:00:00  2022-11-18 00:00:00
# std      0.221359                         NaN                  NaN
#
#                   Total Duration    Air Days
# count                        250  250.000000
# mean      0 days 18:59:20.880000   55.524000
# min              0 days 00:20:00    0.000000
# 25%              0 days 16:00:00   50.000000
# 50%              0 days 18:40:00   50.000000
# 75%              0 days 20:00:00   61.500000
# max              3 days 22:30:00  295.000000
# std    0 days 11:02:20.527714130   34.562228

# %% [markdown]
# 1. In which years were the highest-rated kdramas released?

# %%
df.groupby('Year of release')['Name'].count().sort_values(ascending=False).head(5)
# Out:
# Year of release
# 2021    39
# 2019    37
# 2020    35
# 2022    32
# 2017    27
# Name: Name, dtype: int64

# %% [markdown]
# 2. What is the average rating of kdramas per year?

# %%
df.groupby('Year of release')['Rating'].mean().sort_values(ascending=False)
# Out:
# Year of release
# 2021    8.605128
# 2003    8.600000
# 2016    8.600000
# 2020    8.560000
# 2022    8.546875
# 2017    8.544444
# 2018    8.533333
# 2014    8.528571
# 2010    8.500000
# 2015    8.500000
# 2009    8.500000
# 2019    8.478378
# 2013    8.463636
# 2012    8.400000
# 2011    8.375000
# 2007    8.300000
# 2006    8.300000
# Name: Rating, dtype: float64

# %% [markdown]
# 3. Which dramas have the highest ratings?

# %%
df[['Name', 'Rating']].sort_values(by='Rating', ascending=False).head(10)
# Out:
#                          Name  Rating
# 0              Move to Heaven     9.2
# 1              Flower of Evil     9.1
# 2           Hospital Playlist     9.1
# 3         Hospital Playlist 2     9.1
# 4                   My Mister     9.1
# 5                  Reply 1988     9.1
# 6           Weak Hero Class 1     9.1
# 7             Prison Playbook     9.1
# 8            Alchemy of Souls     9.0
# 9  Extraordinary Attorney Woo     9.0

# %% [markdown]
# 4. What is the best kdrama in every Genre?

# %%
df_exploded = df.explode('Genre')

df_exploded['Genre'].unique()
first_kdramas_per_genre = df_exploded.groupby('Genre', as_index=False).first()
first_kdramas_per_genre = first_kdramas_per_genre[['Genre', 'Name', 'Year of release']]
first_kdramas_per_genre
# Out:
#             Genre                             Name  Year of release
# 0          Action                Weak Hero Class 1             2022
# 1       Adventure                          Dong Yi             2010
# 2        Business                          Misaeng             2014
# 3          Comedy                       Reply 1988             2015
# 4           Crime                   Flower of Evil             2020
# 5           Drama                   Move to Heaven             2021
# 6          Family                   Move to Heaven             2021
# 7         Fantasy                 Alchemy of Souls             2022
# 8            Food              Jewel in the Palace             2003
# 9      Friendship                Hospital Playlist             2020
# 10     Historical                 Alchemy of Souls             2022
# 11         Horror                Kingdom: Season 2             2020
# 12            Law       Extraordinary Attorney Woo             2022
# 13           Life                   Move to Heaven             2021
# 14        Medical                Hospital Playlist             2020
# 15      Melodrama                   Flower of Evil             2020
# 16       Military             Crash Landing on You             2019
# 17          Music             Thirty But Seventeen             2018
# 18        Mystery                        Mr. Queen             2020
# 19      Political             Crash Landing on You             2019
# 20  Psychological                        My Mister             2018
# 21        Romance                   Flower of Evil             2020
# 22         School                   Go Back Couple             2017
# 23         Sci-Fi                           Signal             2016
# 24         Sitcom          The Sound of Your Heart             2016
# 25         Sports  Weightlifting Fairy Kim Bok Joo             2016
# 26   Supernatural                Kingdom: Season 2             2020
# 27       Thriller                   Flower of Evil             2020
# 28          Youth                       Reply 1988             2015

# %% [markdown]
# 5. Who are the most frequently casted actors?
